# %%
import tensorflow as tf
model = tf.keras.models.load_model('artifacts/final_lstm_savedmodel')
# or load the .keras inference file
model = tf.keras.models.load_model('artifacts/final_lstm_model_inference.keras')
